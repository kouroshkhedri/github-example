# %% [markdown]
# # Question1

# %%
import pandas as pd

# %%
admin_site1 = pd.read_csv("administrative_site1.csv")
admin_site2 = pd.read_csv("administrative_site2.csv")
lab = pd.read_csv("lab.csv")

# %%
admin_site1['admission_date'] = pd.to_datetime(admin_site1['admission_date'])

# %%
admin_site1['discharge_date'] = pd.to_datetime(admin_site1['discharge_date'])

# %%
admin_site1.head(15)
# Out:
#       ID admission_date admission_time discharge_date discharge_time  \
# 0   1003     2002-04-25          07:47     2002-05-08          12:02
# 1   1008     2004-09-02          07:49     2005-02-01          10:07
# 2   1009     2011-01-01          17:08     2011-06-26          08:16
# 3   1019     2000-03-09          10:15     2000-05-29          22:38
# 4   1030     2003-11-18          08:31     2004-01-28          13:21
# 5   1031     2008-09-11          12:09     2009-01-11          01:47
# 6   1036     2000-08-20          19:05     2000-12-31          07:24
# 7   1037     2013-10-15          05:11     2013-11-07          13:54
# 8   1071     2009-07-05          05:28     2009-07-15          06:57
# 9   1074     2014-12-23          15:16     2015-04-24          19:35
# 10  1092     2005-03-09          09:51     2005-03-13          16:22
# 11  1105     2004-02-05          03:17     2004-07-31          02:16
# 12  1131     2009-07-22          19:56     2009-11-09          15:56
# ...

# %%
admin_site2['admission.date'] = pd.to_datetime(admin_site2['admission.date'])
admin_site2['discharge.date'] = pd.to_datetime(admin_site2['discharge.date'])

# %%
admin_site2.head(15)
# Out:
#     subjectid admission.date admission.time discharge.date discharge.time  \
# 0        1005     2005-12-04          03:43     2006-04-29          15:18
# 1        1033     2007-09-09          03:26     2007-10-27          06:06
# 2        1038     2001-08-21          09:40     2002-02-12          10:50
# 3        1042     2007-04-11          01:13     2007-09-28          18:37
# 4        1044     2006-06-28          10:29     2006-08-24          20:22
# 5        1054     2004-06-12          20:30     2004-10-04          13:46
# 6        1056     2002-11-19          08:17     2002-11-25          06:32
# 7        1082     2012-09-05          23:29     2013-03-21          19:29
# 8        1086     2000-09-12          23:31     2000-09-24          21:34
# 9        1094     2011-05-27          01:50     2011-10-04          17:06
# 10       1101     2001-12-20          06:08     2002-05-13          05:55
# 11       1104     2007-09-13          11:29     2007-11-09          15:27
# ...

# %%
lab.head(15)
# Out:
#       ID          test_name test_code result_unit  result_value result_date  \
# 0   1003      Sodium plasma      NAPL      mmol/L         137.0  2002-05-07
# 1   1003  Creatinine plasma    CREAPL      umol/L         537.0  2002-05-02
# 2   1005        Urea plasma    UREAPL      mmol/L          37.3  2005-12-04
# 3   1008      Sodium plasma      NAPL      mmol/L         143.1  2004-10-19
# 4   1008        Urea plasma    UREAPL      mmol/L          13.0  2004-11-05
# 5   1009      Sodium plasma      NAPL      mmol/L         145.7  2011-04-25
# 6   1009  Creatinine plasma    CREAPL      umol/L          73.1  2011-06-10
# 7   1019    Chloride plasma      CLPL      mmol/L          77.3  2000-03-31
# 8   1019  Creatinine plasma    CREAPL      umol/L         367.9  2000-05-22
# 9   1030   Potassium plasma       KPL      mmol/L           6.5  2003-12-07
# 10  1030      Sodium plasma      NAPL      mmol/L         146.0  2003-11-20
# ...

# %%
admin_site2_new = admin_site2.rename(columns={'subjectid':'ID','admission.date':'admission_date','admission.time':'admission_time','discharge.date':'discharge_date','discharge.time':'discharge_time','hospital':'hospital_ID','disease.status':'disease_status'})

# %%
admin = pd.concat([admin_site1,admin_site2_new],axis=0,sort=False)
admin.reset_index(drop=True)
# Out:
#         ID admission_date admission_time discharge_date discharge_time  \
# 0     1003     2002-04-25          07:47     2002-05-08          12:02
# 1     1008     2004-09-02          07:49     2005-02-01          10:07
# 2     1009     2011-01-01          17:08     2011-06-26          08:16
# 3     1019     2000-03-09          10:15     2000-05-29          22:38
# 4     1030     2003-11-18          08:31     2004-01-28          13:21
# 5     1031     2008-09-11          12:09     2009-01-11          01:47
# 6     1036     2000-08-20          19:05     2000-12-31          07:24
# 7     1037     2013-10-15          05:11     2013-11-07          13:54
# 8     1071     2009-07-05          05:28     2009-07-15          06:57
# 9     1074     2014-12-23          15:16     2015-04-24          19:35
# 10    1092     2005-03-09          09:51     2005-03-13          16:22
# 11    1105     2004-02-05          03:17     2004-07-31          02:16
# ...

# %%
admin.head()
# Out:
#      ID admission_date admission_time discharge_date discharge_time  \
# 0  1003     2002-04-25          07:47     2002-05-08          12:02
# 1  1008     2004-09-02          07:49     2005-02-01          10:07
# 2  1009     2011-01-01          17:08     2011-06-26          08:16
# 3  1019     2000-03-09          10:15     2000-05-29          22:38
# 4  1030     2003-11-18          08:31     2004-01-28          13:21
#
#                   hospital_ID gender   age  disease_status
# 0  St. Joseph's Health Centre      F   NaN               0
# 1      St. Michael's Hospital      M  58.0               0
# 2      St. Michael's Hospital    NaN   NaN               1
# 3      St. Michael's Hospital      M   NaN               1
# 4      St. Michael's Hospital      F  72.0               0

# %%
admin_site1.shape
# Out:
# (787, 9)

# %%
admin_site2.shape
# Out:
# (1213, 9)

# %%
admin.shape
# Out:
# (2000, 9)

# %% [markdown]
# # Question 2

# %%
admin['admission_date'].map(str) + ' ' + admin['admission_time'].map(str)
# Out:
# 0       2002-04-25 00:00:00 07:47
# 1       2004-09-02 00:00:00 07:49
# 2       2011-01-01 00:00:00 17:08
# 3       2000-03-09 00:00:00 10:15
# 4       2003-11-18 00:00:00 08:31
# 5       2008-09-11 00:00:00 12:09
# 6       2000-08-20 00:00:00 19:05
# 7       2013-10-15 00:00:00 05:11
# 8       2009-07-05 00:00:00 05:28
# 9       2014-12-23 00:00:00 15:16
# 10      2005-03-09 00:00:00 09:51
# 11      2004-02-05 00:00:00 03:17
# 12      2009-07-22 00:00:00 19:56
# 13      2006-03-23 00:00:00 12:18
# 14      2008-11-25 00:00:00 15:21
# 15      2014-06-30 00:00:00 12:07
# 16      2002-03-09 00:00:00 01:10
# 17      2013-04-23 00:00:00 10:00
# 18      2010-12-03 00:00:00 11:02
# 19      2011-04-01 00:00:00 18:25
# 20      2011-06-14 00:00:00 08:44
# 21      2001-06-21 00:00:00 19:30
# 22      2001-07-17 00:00:00 12:55
# 23      2001-03-31 00:00:00 11:16
# 24      2012-09-24 00:00:00 11:27
# 25      2009-12-30 00:00:00 11:43
# 26      2004-09-12 00:00:00 13:36
# ...

# %%
admin['Start_date'] = pd.to_datetime(admin['admission_date'].map(str) + ' ' + admin['admission_time'].map(str))

# %%
admin['End_date'] = pd.to_datetime(admin['discharge_date'].map(str) + ' ' + admin['discharge_time'].map(str))

# %%
admin.head()
# Out:
#      ID admission_date admission_time discharge_date discharge_time  \
# 0  1003     2002-04-25          07:47     2002-05-08          12:02
# 1  1008     2004-09-02          07:49     2005-02-01          10:07
# 2  1009     2011-01-01          17:08     2011-06-26          08:16
# 3  1019     2000-03-09          10:15     2000-05-29          22:38
# 4  1030     2003-11-18          08:31     2004-01-28          13:21
#
#                   hospital_ID gender   age  disease_status  \
# 0  St. Joseph's Health Centre      F   NaN               0
# 1      St. Michael's Hospital      M  58.0               0
# 2      St. Michael's Hospital    NaN   NaN               1
# 3      St. Michael's Hospital      M   NaN               1
# 4      St. Michael's Hospital      F  72.0               0
#
#            Start_date            End_date
# 0 2002-04-25 07:47:00 2002-05-08 12:02:00
# 1 2004-09-02 07:49:00 2005-02-01 10:07:00
# 2 2011-01-01 17:08:00 2011-06-26 08:16:00
# ...

# %%
import numpy as np
admin['length_of_stay'] = admin['End_date'] - admin['Start_date']
admin['length_of_stay'] = admin['length_of_stay']/np.timedelta64(1,'D')

# %%
admin.head()
# Out:
#      ID admission_date admission_time discharge_date discharge_time  \
# 0  1003     2002-04-25          07:47     2002-05-08          12:02
# 1  1008     2004-09-02          07:49     2005-02-01          10:07
# 2  1009     2011-01-01          17:08     2011-06-26          08:16
# 3  1019     2000-03-09          10:15     2000-05-29          22:38
# 4  1030     2003-11-18          08:31     2004-01-28          13:21
#
#                   hospital_ID gender   age  disease_status  \
# 0  St. Joseph's Health Centre      F   NaN               0
# 1      St. Michael's Hospital      M  58.0               0
# 2      St. Michael's Hospital    NaN   NaN               1
# 3      St. Michael's Hospital      M   NaN               1
# 4      St. Michael's Hospital      F  72.0               0
#
#            Start_date            End_date  length_of_stay
# 0 2002-04-25 07:47:00 2002-05-08 12:02:00       13.177083
# 1 2004-09-02 07:49:00 2005-02-01 10:07:00      152.095833
# ...

# %%
admin.groupby('hospital_ID')['length_of_stay'].mean()
# Out:
# hospital_ID
# Mount Sinai Hospital                  99.966877
# St. Joseph's Health Centre            93.129789
# St. Michael's Hospital               102.214865
# Sunnybrook Health Sciences Centre     97.608317
# Toronto Western Hospital             100.880574
# Name: length_of_stay, dtype: float64

# %% [markdown]
# # Question 3

# %%
lab.head(10)
# Out:
#      ID          test_name test_code result_unit  result_value result_date  \
# 0  1003      Sodium plasma      NAPL      mmol/L         137.0  2002-05-07
# 1  1003  Creatinine plasma    CREAPL      umol/L         537.0  2002-05-02
# 2  1005        Urea plasma    UREAPL      mmol/L          37.3  2005-12-04
# 3  1008      Sodium plasma      NAPL      mmol/L         143.1  2004-10-19
# 4  1008        Urea plasma    UREAPL      mmol/L          13.0  2004-11-05
# 5  1009      Sodium plasma      NAPL      mmol/L         145.7  2011-04-25
# 6  1009  Creatinine plasma    CREAPL      umol/L          73.1  2011-06-10
# 7  1019    Chloride plasma      CLPL      mmol/L          77.3  2000-03-31
# 8  1019  Creatinine plasma    CREAPL      umol/L         367.9  2000-05-22
# 9  1030   Potassium plasma       KPL      mmol/L           6.5  2003-12-07
#
#   result_time        provider_name
# 0       05:26          Wray, Jamie
# 1       02:02      Young, Jennifer
# 2       16:02       Glass, Caitlin
# ...

# %%
merged_df = pd.merge(admin,lab,on='ID')
merged_df
# Out:
#         ID admission_date admission_time discharge_date discharge_time  \
# 0     1003     2002-04-25          07:47     2002-05-08          12:02
# 1     1003     2002-04-25          07:47     2002-05-08          12:02
# 2     1008     2004-09-02          07:49     2005-02-01          10:07
# 3     1008     2004-09-02          07:49     2005-02-01          10:07
# 4     1009     2011-01-01          17:08     2011-06-26          08:16
# 5     1009     2011-01-01          17:08     2011-06-26          08:16
# 6     1019     2000-03-09          10:15     2000-05-29          22:38
# 7     1019     2000-03-09          10:15     2000-05-29          22:38
# 8     1030     2003-11-18          08:31     2004-01-28          13:21
# 9     1030     2003-11-18          08:31     2004-01-28          13:21
# 10    1031     2008-09-11          12:09     2009-01-11          01:47
# 11    1036     2000-08-20          19:05     2000-12-31          07:24
# ...

# %% [markdown]
# # Question 4

# %% [markdown]
# I believe using barchart or histogram both can work in this case because 'hospital_ID' is categorical data and 'length_of_stay' is numerical data so each hospital_ID has number of lengh_of_stays related to. The barplot is shown as below.

# %% [markdown]
# # Question 5

# %%
import matplotlib.pyplot as plt

plt.bar(admin['hospital_ID'], admin['length_of_stay'], label = "number of each stay")

plt.xlabel('hospital id')
plt.ylabel('lengh of stay')
plt.title('relationship between hospital_ID and lengh_of_stay')
plt.legend()
plt.show()

# %% [markdown]
# # Question 6

# %%
lab_wide = lab.pivot_table(index='ID', columns='test_name', values='result_value', aggfunc='min')
lab_wide
# Out:
# test_name  Bicarbonate plasma  Chloride plasma  Creatinine plasma  \
# ID
# 1003                      NaN              NaN              537.0
# 1005                      NaN              NaN                NaN
# 1008                      NaN              NaN                NaN
# 1009                      NaN              NaN               73.1
# 1019                      NaN             77.3              367.9
# 1030                      NaN              NaN                NaN
# 1031                      NaN              NaN                NaN
# 1033                      NaN              NaN                NaN
# 1036                      NaN              NaN                NaN
# 1037                      NaN             98.6                NaN
# 1038                      NaN              NaN              418.5
# 1042                      NaN              NaN                NaN
# 1044                      NaN            110.4                NaN
# ...

# %%
lab_wide['Urea plasma'] = lab_wide['Urea plasma'].fillna(0)
lab_wide
# Out:
# test_name  Bicarbonate plasma  Chloride plasma  Creatinine plasma  \
# ID
# 1003                      NaN              NaN              537.0
# 1005                      NaN              NaN                NaN
# 1008                      NaN              NaN                NaN
# 1009                      NaN              NaN               73.1
# 1019                      NaN             77.3              367.9
# 1030                      NaN              NaN                NaN
# 1031                      NaN              NaN                NaN
# 1033                      NaN              NaN                NaN
# 1036                      NaN              NaN                NaN
# 1037                      NaN             98.6                NaN
# 1038                      NaN              NaN              418.5
# 1042                      NaN              NaN                NaN
# 1044                      NaN            110.4                NaN
# ...

# %%
lab_wide['Urea plasma'].mean()
# Out:
# 17.249065934065932

# %% [markdown]
# # Question 7

# %%
lab = pd.read_csv("lab.csv")
lab_impute = lab
lab_impute
# Out:
#         ID           test_name test_code result_unit  result_value  \
# 0     1003       Sodium plasma      NAPL      mmol/L         137.0
# 1     1003   Creatinine plasma    CREAPL      umol/L         537.0
# 2     1005         Urea plasma    UREAPL      mmol/L          37.3
# 3     1008       Sodium plasma      NAPL      mmol/L         143.1
# 4     1008         Urea plasma    UREAPL      mmol/L          13.0
# 5     1009       Sodium plasma      NAPL      mmol/L         145.7
# 6     1009   Creatinine plasma    CREAPL      umol/L          73.1
# 7     1019     Chloride plasma      CLPL      mmol/L          77.3
# 8     1019   Creatinine plasma    CREAPL      umol/L         367.9
# 9     1030    Potassium plasma       KPL      mmol/L           6.5
# 10    1030       Sodium plasma      NAPL      mmol/L         146.0
# 11    1031       Sodium plasma      NAPL      mmol/L         148.0
# 12    1033       Sodium plasma      NAPL      mmol/L         129.9
# ...

# %%
lab_impute['result_date'] = pd.to_datetime(lab_impute['result_date'])

# %%
#lab_impute.loc[lab_impute.result_date == '2002' , 'result_value'] = 0
#lab_impute
lab_impute.loc[lab_impute['result_date'].map(lambda x : x.year == 2002) , 'result_value'] = 0
lab_impute
# Out:
#         ID           test_name test_code result_unit  result_value  \
# 0     1003       Sodium plasma      NAPL      mmol/L           0.0
# 1     1003   Creatinine plasma    CREAPL      umol/L           0.0
# 2     1005         Urea plasma    UREAPL      mmol/L          37.3
# 3     1008       Sodium plasma      NAPL      mmol/L         143.1
# 4     1008         Urea plasma    UREAPL      mmol/L          13.0
# 5     1009       Sodium plasma      NAPL      mmol/L         145.7
# 6     1009   Creatinine plasma    CREAPL      umol/L          73.1
# 7     1019     Chloride plasma      CLPL      mmol/L          77.3
# 8     1019   Creatinine plasma    CREAPL      umol/L         367.9
# 9     1030    Potassium plasma       KPL      mmol/L           6.5
# 10    1030       Sodium plasma      NAPL      mmol/L         146.0
# 11    1031       Sodium plasma      NAPL      mmol/L         148.0
# 12    1033       Sodium plasma      NAPL      mmol/L         129.9
# ...

# %%
#admin.groupby('hospital_ID')['length_of_stay'].mean()
#lab_impute['result_value'].fillna(0, inplace=True)
#lab_impute
mean_one = lab_impute.groupby('test_name')['result_value'].mean()
mean_one
# Out:
# test_name
# Bicarbonate plasma     53.803859
# Chloride plasma       121.517066
# Creatinine plasma     291.902093
# Potassium plasma        5.950735
# Sodium plasma         126.071579
# Urea plasma            69.797881
# Name: result_value, dtype: float64

# %%
#lab_impute['result_value'] = lab_impute['result_value'].replace(0.0, lab_impute.groupby('test_name')['result_value'].mean())
lab_impute.loc[lab_impute['test_name'].map(lambda x : x == 'Bicarbonate plasma') & lab_impute['result_value'].map(lambda x : x == 0.0), 'result_value'] = 53.80
lab_impute.loc[lab_impute['test_name'].map(lambda x : x == 'Sodium plasma') & lab_impute['result_value'].map(lambda x : x == 0.0), 'result_value'] = 126.07
lab_impute.loc[lab_impute['test_name'].map(lambda x : x == 'Creatinine plasma') & lab_impute['result_value'].map(lambda x : x == 0.0), 'result_value'] = 291.90
lab_impute.loc[lab_impute['test_name'].map(lambda x : x == 'Chloride plasma') & lab_impute['result_value'].map(lambda x : x == 0.0), 'result_value'] = 121.51
lab_impute.loc[lab_impute['test_name'].map(lambda x : x == 'Potassium plasma') & lab_impute['result_value'].map(lambda x : x == 0.0), 'result_value'] = 5.95
lab_impute.loc[lab_impute['test_name'].map(lambda x : x == 'Urea plasma') & lab_impute['result_value'].map(lambda x : x == 0.0), 'result_value'] = 69.79

# %%
lab_impute
# Out:
#         ID           test_name test_code result_unit  result_value  \
# 0     1003       Sodium plasma      NAPL      mmol/L        126.07
# 1     1003   Creatinine plasma    CREAPL      umol/L        291.90
# 2     1005         Urea plasma    UREAPL      mmol/L         37.30
# 3     1008       Sodium plasma      NAPL      mmol/L        143.10
# 4     1008         Urea plasma    UREAPL      mmol/L         13.00
# 5     1009       Sodium plasma      NAPL      mmol/L        145.70
# 6     1009   Creatinine plasma    CREAPL      umol/L         73.10
# 7     1019     Chloride plasma      CLPL      mmol/L         77.30
# 8     1019   Creatinine plasma    CREAPL      umol/L        367.90
# 9     1030    Potassium plasma       KPL      mmol/L          6.50
# 10    1030       Sodium plasma      NAPL      mmol/L        146.00
# 11    1031       Sodium plasma      NAPL      mmol/L        148.00
# 12    1033       Sodium plasma      NAPL      mmol/L        129.90
# ...

# %% [markdown]
# # Question 8

# %%
lab
# Out:
#         ID           test_name test_code result_unit  result_value  \
# 0     1003       Sodium plasma      NAPL      mmol/L        126.07
# 1     1003   Creatinine plasma    CREAPL      umol/L        291.90
# 2     1005         Urea plasma    UREAPL      mmol/L         37.30
# 3     1008       Sodium plasma      NAPL      mmol/L        143.10
# 4     1008         Urea plasma    UREAPL      mmol/L         13.00
# 5     1009       Sodium plasma      NAPL      mmol/L        145.70
# 6     1009   Creatinine plasma    CREAPL      umol/L         73.10
# 7     1019     Chloride plasma      CLPL      mmol/L         77.30
# 8     1019   Creatinine plasma    CREAPL      umol/L        367.90
# 9     1030    Potassium plasma       KPL      mmol/L          6.50
# 10    1030       Sodium plasma      NAPL      mmol/L        146.00
# 11    1031       Sodium plasma      NAPL      mmol/L        148.00
# 12    1033       Sodium plasma      NAPL      mmol/L        129.90
# ...

# %%
lab[lab['provider_name'].str.contains("Jessica") | lab['provider_name'].str.contains("Kelsey")]
#lab[lab['provider_name'].str.contains("Kelsey")]
# Out:
#         ID           test_name test_code result_unit  result_value  \
# 27    1071       Sodium plasma      NAPL      mmol/L        141.50
# 42    1127  Bicarbonate plasma    TCO2PL      mmol/L         53.80
# 46    1143       Sodium plasma      NAPL      mmol/L        121.20
# 177   1620       Sodium plasma      NAPL      mmol/L        129.40
# 301   2059   Creatinine plasma    CREAPL      umol/L        291.90
# 326   2135     Chloride plasma      CLPL      mmol/L        121.51
# 483   2681       Sodium plasma      NAPL      mmol/L        140.60
# 524   2841     Chloride plasma      CLPL      mmol/L        149.80
# 534   2888   Creatinine plasma    CREAPL      umol/L        291.90
# 552   2917         Urea plasma    UREAPL      mmol/L         99.60
# 651   3142  Bicarbonate plasma    TCO2PL      mmol/L         53.80
# 655   3152    Potassium plasma       KPL      mmol/L          5.70
# 775   3755    Potassium plasma       KPL      mmol/L          3.40
# ...

# %%
#mean_one = lab_impute.groupby('test_name')['result_value'].mean()
v3 = lab[lab['test_code'].str.contains("NAPL")]
v3
# Out:
#         ID      test_name test_code result_unit  result_value result_date  \
# 0     1003  Sodium plasma      NAPL      mmol/L        126.07  2002-05-07
# 3     1008  Sodium plasma      NAPL      mmol/L        143.10  2004-10-19
# 5     1009  Sodium plasma      NAPL      mmol/L        145.70  2011-04-25
# 10    1030  Sodium plasma      NAPL      mmol/L        146.00  2003-11-20
# 11    1031  Sodium plasma      NAPL      mmol/L        148.00  2008-11-02
# 12    1033  Sodium plasma      NAPL      mmol/L        129.90  2007-09-29
# 16    1037  Sodium plasma      NAPL      mmol/L        140.80  2013-11-05
# 18    1038  Sodium plasma      NAPL      mmol/L        142.20  2001-09-04
# 20    1042  Sodium plasma      NAPL      mmol/L        143.40  2007-06-03
# 21    1042  Sodium plasma      NAPL      mmol/L        141.40  2007-06-09
# 24    1054  Sodium plasma      NAPL      mmol/L        147.50  2004-08-01
# 25    1056  Sodium plasma      NAPL      mmol/L        126.07  2002-11-22
# ...

# %%
v3['result_value'].mean()
# Out:
# 134.27517703349312

# %%
#create admin.csv 
admin.to_csv(r'C:\Users\Kourosh Khedri IMSC\Desktop\GEMINI test_4 May 2020\admin.csv',index = False, header=True)

# %%
age = admin['age'].tolist()
gender = admin['gender'].tolist()
hospital_ID = admin['hospital_ID'].tolist()
disease_status = admin['disease_status'].tolist()

# %% [markdown]
# # Question 9

# %%
#this will be a multiple linear regression because we have more then one independent variable
#from numpy import genfromtxt
#admin_data = genfromtxt('admin.csv', delimiter=',')

import statsmodels.api as sm

X = admin[['age', 'gender', 'hospital_ID']]
y= admin['disease_status']
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-332-751298e3b8f9> in <module>()
#       9 X = sm.add_constant(X)
#      10
# ---> 11 model = sm.OLS(y, X).fit()
#      12 predictions = model.predict(X)
#      13
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     815                  **kwargs):
#     816         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 817                                   hasconst=hasconst, **kwargs)
#     818         if "weights" in self._init_keys:
#     819             self._init_keys.remove("weights")
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     661             weights = weights.squeeze()
# ...

# %% [markdown]
# ## Question 10

# %%
merged_df
# Out:
#         ID admission_date admission_time discharge_date discharge_time  \
# 0     1003     2002-04-25          07:47     2002-05-08          12:02
# 1     1003     2002-04-25          07:47     2002-05-08          12:02
# 2     1008     2004-09-02          07:49     2005-02-01          10:07
# 3     1008     2004-09-02          07:49     2005-02-01          10:07
# 4     1009     2011-01-01          17:08     2011-06-26          08:16
# 5     1009     2011-01-01          17:08     2011-06-26          08:16
# 6     1019     2000-03-09          10:15     2000-05-29          22:38
# 7     1019     2000-03-09          10:15     2000-05-29          22:38
# 8     1030     2003-11-18          08:31     2004-01-28          13:21
# 9     1030     2003-11-18          08:31     2004-01-28          13:21
# 10    1031     2008-09-11          12:09     2009-01-11          01:47
# 11    1036     2000-08-20          19:05     2000-12-31          07:24
# ...

# %%
test_code_list = merged_df['test_code']
test_code_list
# Out:
# 0         NAPL
# 1       CREAPL
# 2         NAPL
# 3       UREAPL
# 4         NAPL
# 5       CREAPL
# 6         CLPL
# 7       CREAPL
# 8          KPL
# 9         NAPL
# 10        NAPL
# 11         KPL
# 12         KPL
# 13        NAPL
# 14        CLPL
# 15        NAPL
# 16        NAPL
# 17        NAPL
# 18      UREAPL
# 19        NAPL
# 20         KPL
# 21      UREAPL
# 22      CREAPL
# 23         KPL
# 24        NAPL
# 25        NAPL
# 26      UREAPL
# 27      UREAPL
# 28         KPL
# 29        NAPL
#          ...
# 2970      NAPL
# 2971    CREAPL
# 2972    UREAPL
# 2973       KPL
# 2974      NAPL
# 2975      NAPL
# 2976    UREAPL
# 2977    UREAPL
# 2978    TCO2PL
# 2979    CREAPL
# 2980    UREAPL
# 2981    CREAPL
# 2982      NAPL
# 2983    UREAPL
# 2984      CLPL
# 2985    CREAPL
# 2986      NAPL
# 2987    TCO2PL
# 2988      NAPL
# 2989    UREAPL
# 2990      CLPL
# 2991      NAPL
# 2992    CREAPL
# 2993    CREAPL
# 2994      NAPL
# 2995      NAPL
# 2996       KPL
# ...

# %%
hospital_ID_list = merged_df['hospital_ID']
hospital_ID_list
# Out:
# 0              St. Joseph's Health Centre
# 1              St. Joseph's Health Centre
# 2                  St. Michael's Hospital
# 3                  St. Michael's Hospital
# 4                  St. Michael's Hospital
# 5                  St. Michael's Hospital
# 6                  St. Michael's Hospital
# 7                  St. Michael's Hospital
# 8                  St. Michael's Hospital
# 9                  St. Michael's Hospital
# 10                 St. Michael's Hospital
# 11                 St. Michael's Hospital
# 12                 St. Michael's Hospital
# 13                 St. Michael's Hospital
# 14                 St. Michael's Hospital
# 15             St. Joseph's Health Centre
# 16             St. Joseph's Health Centre
# 17                 St. Michael's Hospital
# 18                 St. Michael's Hospital
# 19                 St. Michael's Hospital
# 20                 St. Michael's Hospital
# 21             St. Joseph's Health Centre
# ...

# %%
#merged_df
def compute_hospital_mean(test_code:str, hospital_ID:str):
    if (test_code in test_code_list) and (hospital_ID in hospital_ID_list):
        mask = merged_df[['test_code','hospital_ID']]
        new_df = merged_df.loc[mask]
        new_df['result_value'].mean()
        ##return new_df['result_value'].mean();

compute_hospital_mean('KPL','St. Michael\s Hospital')
